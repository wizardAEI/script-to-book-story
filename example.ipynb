# %% [markdown]
# <a href="https://colab.research.google.com/github/wizardAEI/script-to-book-story/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 108.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.4 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=9912e4f15bb5a8be79abf59e5da3a5a02c3668723f5ec5bd16e8d580a17af2bb
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
from PIL import Image
from sentence_transformers import SentenceTransformer, util

# %%
image_model = SentenceTransformer('clip-VIT-B-32')

# %%
text_model = SentenceTransformer('clip-Vit-B-32-multilingual-v1')

# %%
img0 = Image.open('./0.png')
img1 = Image.open('./1.png')
img2 = Image.open('./2.png')
img3 = Image.open('./3.png')
img0
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7C6BA5801390>

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7C6BA5801C60>

# %%
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7C6BA5802590>

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7C6BA58027D0>

# %%
text_vec = text_model.encode(['cute big'])

# %%
image_vecs = image_model.encode([img0, img1, img2, img3])

# %%
for i in range(4):
  s = util.cos_sim(text_vec, image_vecs[i])
  print(i, s)
# Out:
# 0 tensor([[0.2225]])
# 1 tensor([[0.2388]])
# 2 tensor([[0.2282]])
# 3 tensor([[0.2350]])
